# %%
print("Welcome to quiz!")
questions=[
    {
        "question":"1.what is 2+2?",
        "options":["A.3","B.4","C.5","D.6"],
        "answer":"B"
    },
    {
        "question":"2.which keyword is used for function in python?",
        "options":["A.func","B.define","C.def","D.function"],
        "answer":"C"
    },
    {
    "question":"3.which data type is used to store multiple values in python?",
    "options":["A.list","B.float","C.int","D.char"],
    "answer":"A"
}
]
score=0
for q in questions:
    print(q["question"])
    for option in q["options"]:
        print(option)
    user_answer=input("enter your answer: ").upper()
    while user_answer not in ["A","B","C","D"]:
        print("Invalid input!Enter A,B,C or D.")
        user_answer=input("Enter your answer: ").upper()
    if user_answer==q["answer"]:
        print("correct answer!\n")
        score+=1
    else:
        print("Wrong answer\n")
print("Quiz finished!")
print("Your score:",score,"/",len(questions))
percentage=(score/len(questions))*100
print("percentage:",percentage)
# Out:
# Welcome to quiz!
# 1.what is 2+2?
# A.3
# B.4
# C.5
# D.6
# enter your answer:  a
# Wrong answer
#
# 2.which keyword is used for function in python?
# A.func
# B.define
# C.def
# D.function
# enter your answer:  c
# correct answer!
#
# 3.which data type is used to store multiple values in python?
# A.list
# B.float
# C.int
# D.char
# enter your answer:  q
# Invalid input!Enter A,B,C or D.
# Enter your answer:  a
# correct answer!
#
# Quiz finished!
# Your score: 2 / 3
# percentage: 66.66666666666666
